# %% [markdown]
# <a href="https://colab.research.google.com/github/vinitakawale/LogAnalysis/blob/main/LogRAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
import os
import openai
openai.api_key = "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"

# %%
# !pip install llama-index
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.3/914.3 kB 12.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 59.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 5.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.11.2
#     Uninstalling beautifulsoup4-4.11.2:
#       Successfully uninstalled beautifulsoup4-4.11.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# ...

# %%
from llama_index import SimpleDirectoryReader

documents = SimpleDirectoryReader(
    input_files=["./dc_7.csv"]
).load_data()

# %%
print(type(documents), "\n")
print(len(documents), "\n")
print(type(documents[0]))
print(documents[0])
# Out:
# <class 'list'>
#
# 1
#
# <class 'llama_index.schema.Document'>
# Doc ID: 0b26ea37-0ae4-46a5-88d2-4abbc1a1806d
# Text: 0, 2023-11-14 20:07:28.661000+00:00, useast-lab-az-sretest, 30,
# Execution time 1, 2023-11-14 20:07:28.660000+00:00, useast-lab-az-
# sretest, 30, Execution time 2, 2023-11-14 20:07:28.575000+00:00,
# useast-lab-az-sretest, 30, Execution time 3, 2023-11-14
# 20:07:28.249000+00:00, useast-lab-az-sretest, 30, Execution time 4,
# 2023-11-14 20:07:28.247000+0...

# %%
from llama_index import Document

document = Document(text="\n\n".join([doc.text for doc in documents]))

# %%
from llama_index import VectorStoreIndex
from llama_index import ServiceContext
from llama_index.llms import OpenAI

llm = OpenAI(model="gpt-3.5-turbo", temperature=0.1)
service_context = ServiceContext.from_defaults(
    llm=llm, embed_model="local:BAAI/bge-small-en-v1.5"
)
index = VectorStoreIndex.from_documents([document],
                                        service_context=service_context)
# Out:
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [nltk_data] Downloading package punkt to /tmp/llama_index...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
query_engine = index.as_query_engine()

# %%
response = query_engine.query(
    "what actions can I take to resolve the errors in logs ?"
)
print(str(response))
# Out:
# To resolve the errors in the logs, you can take the following actions:
#
# 1. For the error "java.lang.OutOfMemoryError: Java heap space", you can try increasing the heap size allocated to the Java application. This can be done by modifying the JVM arguments or the configuration file of the application.
#
# 2. For the errors related to "Zone map not found for postalCode N3R5L7", you can check the configuration or settings related to the zone maps and ensure that they are properly configured and available for the specified postal code.
#
# 3. If there are any other specific errors mentioned in the logs, you can analyze the error message and stack trace to identify the root cause of the error. Once the root cause is identified, you can take appropriate actions to resolve it. This may involve debugging the code, fixing any issues in the application logic, or updating dependencies.
#
# ...
